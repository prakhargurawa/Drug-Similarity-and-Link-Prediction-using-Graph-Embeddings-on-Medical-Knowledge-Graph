# %% [markdown]
# # Setup Notebook and GPU

# %%
# Monunt google drive to import KEGG dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setting Colab's GPU
# Edit > Notebook Settings > GPU 
# !nvidia-smi -L
# Detailed GPU Information Reference: https://medium.com/analytics-vidhya/the-google-colab-system-specification-check-69d159597417
# !nvidia-smi -q
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-8202b031-95dc-bffa-5378-1f3caa1179dc)

# %%
# !lscpu |grep 'Model name'
# Out:
# Model name:          Intel(R) Xeon(R) CPU @ 2.20GHz

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 2
# initial apicid	: 2
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 2
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 0
# cpu cores	: 2
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 3
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 4
# core id		: 1
# cpu cores	: 2
# apicid		: 3
# initial apicid	: 3
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# # Import relevant libraries

# %%
# %%capture 
# !pip install ampligraph;
# %tensorflow_version 1.x 
import numpy as np
import pandas as pd
import ampligraph
from ampligraph.datasets import load_from_csv
from tabulate import tabulate
ampligraph.__version__

# %% [markdown]
# # Import dataset

# %%
# Load the KEGG dataset
df = load_from_csv('.','drive/My Drive/datasets/KEGG/KEGG50K.txt',sep='\t')
headers = ["Head", "Relationship", "Tail"]
table = tabulate(df[:5], headers, tablefmt="fancy_grid") # tabulate data Reference: https://stackoverflow.com/questions/9712085/numpy-pretty-print-tabular-data
print(table) # output
# Out:
# ╒══════════╤══════════════════╤═══════════╕
# │ Head     │ Relationship     │ Tail      │
# ╞══════════╪══════════════════╪═══════════╡
# │ hsa04024 │ PATHWAY_GENE     │ HSA:51196 │
# ├──────────┼──────────────────┼───────────┤
# │ D02042   │ DRUG_TARGET_GENE │ HSA:5139  │
# ├──────────┼──────────────────┼───────────┤
# │ N00399   │ NETWORK_GENE     │ HSA:2790  │
# ├──────────┼──────────────────┼───────────┤
# │ hsa04912 │ PATHWAY_GENE     │ HSA:6654  │
# ├──────────┼──────────────────┼───────────┤
# │ H00342   │ DISEASE_GENE     │ HSA:6556  │
# ╘══════════╧══════════════════╧═══════════╛

# %% [markdown]
# # Split dataset

# %%
from ampligraph.evaluation import train_test_split_no_unseen 
num_test = int(len(df) * (20 / 100))
data = {}
data['train'], data['test'] = train_test_split_no_unseen(df, test_size=num_test, seed=0, allow_duplication=False)

# %%
print('Train set size: ', data['train'].shape)
print('Test set size: ', data['test'].shape)
# Out:
# Train set size:  (50464, 3)
# Test set size:  (12616, 3)

# %% [markdown]
# # Graph embedding algorithm -  ComplEx

# %%
from ampligraph.latent_features import ComplEx

# %% [markdown]
# #### Creating ComplEx graphical embedding model
# *   **k (int)** – Embedding space dimensionality.
# *   **eta (int)** – The number of negatives that must be generated at runtime during training for each positive.
# *   **epochs (int)** – The iterations of the training loop.
# *   **batches_count (int)** – The number of batches in which the training set must be split during the training loop.
# *   **seed (int)** – The seed used by the internal random numbers generator.
# *   **optimizer (string)** – The optimizer used to minimize the loss function. Choose between ‘sgd’, ‘adagrad’, ‘adam’, ‘momentum’.
# *   **optimizer_params (dict)** –
# Arguments specific to the optimizer, passed as a dictionary. {’lr’ (float),’momentum’ (float)}
# *   **loss (string)** –
# The type of loss function to use during training.
# *   **regularizer (string)** –
# The regularization strategy to use with the loss function
# *  **regularizer_params (dict)** –
# Dictionary of regularizer-specific hyperparameters. For example, if p=1 the function will perform L1 regularization. L2 regularization is obtained with p=2.
# *  **verbose (bool)** – Verbose mode.

# %%
model = ComplEx(batches_count=100, 
                seed=0, 
                epochs=200, 
                k=200, 
                eta=5,
                optimizer='adam', 
                optimizer_params={'lr':1e-3},
                loss='multiclass_nll',                     # Multiclass NLL Loss Reference: https://docs.ampligraph.org/en/latest/generated/ampligraph.latent_features.NLLMulticlass.html#ampligraph.latent_features.NLLMulticlass
                regularizer='LP', 
                regularizer_params={'p':3,'lambda':1e-5},  # The nuclear 3-norm proposed in the ComplEx-N3 from paper LUO18, proves to be effective for DistMult and ComplEx Reference: https://github.com/DeepGraphLearning/KnowledgeGraphEmbedding/issues/6 
                verbose=True)

# Possible loss functions: (Pairwise, max-margin loss),(Absolute margin, max-margin loss),(Self adversarial sampling loss),(Negative log-likelihood loss),(Multiclass NLL Loss),(Binary Cross Entropy Loss)
# Default initializer : Xaviers
# LUO18 : Timothee Lacroix, Nicolas Usunier, and Guillaume Obozinski. Canonical tensor decomposition for knowledge base completion. In International Conference on Machine Learning, 2869–2878. 2018.

# %% [markdown]
# #### Filtering negatives
# AmpliGraph aims to follow scikit-learn's ease-of-use design philosophy and simplify everything down to fit, evaluate, and predict functions. However, there are some knowledge graph specific steps we must take to ensure our model can be trained and evaluated correctly. The first of these is defining the filter that will be used to ensure that no negative statements generated by the corruption procedure are actually positives. This is simply done by concatenating our train and test sets. Now when negative triples are generated by the corruption strategy, we can check that they aren't actually true statements.

# %%
positives_filter = df

# %% [markdown]
# #### Fitting model

# %%
import tensorflow as tf
import time
tf.logging.set_verbosity(tf.logging.ERROR)
start_time = time.time()
model.fit(data['train'], early_stopping = False)
print("Execution time: %s seconds." % (time.time() - start_time))
# Out:
# Average ComplEx Loss:   0.022336: 100%|██████████| 200/200 [01:53<00:00,  1.76epoch/s]
# Execution time: 119.75966167449951 seconds.

# %% [markdown]
# #### Saving model

# %%
from ampligraph.latent_features import save_model, restore_model
save_model(model, './ComplEx_model_Dim200_Adam_Muliclass.pkl')
"""
del model
model = restore_model('./ComplEx_model_Dim200_Adam_Muliclass.pkl')
if model.is_fitted:
    print('The model is fit!')
else:
    print('The model is not fit!')
"""
# Out:
# "\ndel model\nmodel = restore_model('./ComplEx_model_Dim200_Adam_Muliclass.pkl')\nif model.is_fitted:\n    print('The model is fit!')\nelse:\n    print('The model is not fit!')\n"

# %% [markdown]
# #### Evaluating model

# %% [markdown]
# Parameters of evaluate_performance function of Ampligraph:
# - **`X`** - the data to evaluate on. We're going to use our test set to evaluate.
# - **`model`** - the model we previously trained.
# - **`filter_triples`** - will filter out the false negatives generated by the corruption strategy.
# - **`use_default_protocol`** - specifies whether to use the default corruption protocol. If True, then subj and obj are corrupted separately during evaluation.
# - **`verbose`** - will give some nice log statements. Let's leave it on for now.

# %%
from ampligraph.evaluation import evaluate_performance
ranks = evaluate_performance(data['test'], 
                             model=model, 
                             filter_triples=positives_filter,   # Corruption strategy filter defined above 
                             use_default_protocol=True,         # corrupt subj and obj separately while evaluating
                             verbose=True)
# Out:
# 100%|██████████| 12616/12616 [01:22<00:00, 153.67it/s]

# %% [markdown]
# The ranks returned by the evaluate_performance function indicate the rank at which the test set triple was found when performing link prediction using the model.

# %% [markdown]
# We are going to evaluate model using two scores:
#
#
# *   **mrr_score**: function computes the mean of the reciprocal of elements of a vector of rankings ranks.
# *   **hits_at_n_score**: function computes how many elements of a vector of rankings ranks make it to the top n positions.

# %%
from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score

mrr = mrr_score(ranks)
print("MRR: %.2f" % (mrr))

hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))
# Out:
# MRR: 0.38
# Hits@10: 0.55
# Hits@3: 0.42
# Hits@1: 0.30

# %% [markdown]
# #### Generating embeddings for entities

# %%
entities = np.unique(np.concatenate([df[:, 0], df[:, 2]]))
relations = np.unique(df[:, 1])

# %%
entity_embeddings = dict(zip(entities, model.get_embeddings(entities)))

# %%
len(entity_embeddings['D00043'])
# Out:
# 400

# %% [markdown]
# # Link prediction for new entities-relationships
#
# The task of link porediction will help us gather new information about entities and their possible relationship. For example we can perform where a drug and gene are interconnected by relationship 'DRUG_TARGET_GENE' or not.

# %%
# Created few manual samples to check about their feasibility according to our model trained
X_unseen = np.array([
                     ['hsa04024','PATHWAY_GENE','HSA:51196'],     # already in dataset
                     ['D11034','DRUG_EFFICACY_DISEASE','H00409'], # already in dataset
                     ['H00242','DISEASE_GENE','HSA:6338'],        # already in dataset
                     ['D04905','DRUG_TARGET_PATHWAY','hsa05010'], # already in dataset
                     ['N00399','NETWORK_GENE','HSA:2790'],        # already in dataset
                     ['D10845','DRUG_TARGET_PATHWAY','hsa04610'], # already in dataset
                     ['N00060','NETWORK_GENE','HSA:23401'],       # already in dataset
                     ['hsa04024','PATHWAY_GENE','HSA:6336'],      # not in dataset, but might be possible
                     ['D11056','DRUG_TARGET_GENE','HSA:7388'],    # not in dataset, but might be possible
                     ['D11056','DRUG_TARGET_GENE','HSA:3352'],    # not in dataset, but might be possible
                     ['H00242','DISEASE_GENE','HSA:6788'],        # not in dataset, but might be possible
                     ['D04905','DRUG_TARGET_PATHWAY','hsa04728'], # not in dataset, but might be possible
                     ['N00399','NETWORK_GENE','HSA:9217'],        # not in dataset, but might be possible
                     ['D10845','DRUG_TARGET_PATHWAY','hsa05230'], # not in dataset, but might be possible
                     ['N00060','NETWORK_GENE','HSA:5600'],        # not in dataset, but might be possible
                     ['N00327','DISEASE_PATHWAY','HSA:109'],      # impossible
                     ['H00242','DISEASE_GENE','D11034'],          # impossible
                     ['D04905','DRUG_TARGET_PATHWAY','N00399'],   # impossible
                     ['N00399','NETWORK_GENE','N00399'],          # impossible
                     ['D10845','DRUG_TARGET_PATHWAY','D07257'],   # impossible
                     ['N00060','DRUG_TARGET_PATHWAY','hsa04380']  # impossible
])

# %%
unseen_filter = np.array(list({tuple(i) for i in np.vstack((positives_filter, X_unseen))}))

# %%
ranks_unseen = evaluate_performance(
    X_unseen, 
    model=model, 
    filter_triples=unseen_filter,   # Corruption strategy filter defined above 
    corrupt_side = 's+o',
    use_default_protocol=False, # corrupt subj and obj separately while evaluating
    verbose=True
)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 104.17it/s]

# %%
ranks_unseen
# Out:
# array([  411,     1,     1,     1,     3,     1,     4, 18996, 19398,
#           80, 13613,    84, 23056, 10786,  3445,  1751, 12303,  1186,
#         2776, 14832, 21385], dtype=int32)

# %%
scores = model.predict(X_unseen)

# %% [markdown]
# Transforming scores which are in real numbers to probablities (0-1) range for better understanding and comparisions using expit transformation. Although, the probablities are not calibrated.

# %%
scores # direct scores, hard to get insights from these
# Out:
# array([ 3.6522672 , 11.471539  , 11.471505  ,  9.3458395 , 11.556274  ,
#        13.813126  , 12.05084   , -0.5185466 , -0.27560192,  5.4952154 ,
#         0.14726594,  3.8212905 , -1.1676594 ,  0.30169845,  0.9979085 ,
#         1.06176   ,  0.2050918 ,  0.9659963 ,  1.5700122 ,  0.09028471,
#        -0.11375162], dtype=float32)

# %%
from scipy.special import expit
probs = expit(scores)

# %%
pd.DataFrame(list(zip([' '.join(x) for x in X_unseen],
                      ranks_unseen,
                      np.squeeze(scores),
                      np.squeeze(probs))),
             columns=['statement', 'rank', 'score', 'prob']).sort_values("score")
# Out:
#                               statement   rank      score      prob
# 12         N00399 NETWORK_GENE HSA:9217  23056  -1.167659  0.237278
# 7        hsa04024 PATHWAY_GENE HSA:6336  18996  -0.518547  0.373192
# 8      D11056 DRUG_TARGET_GENE HSA:7388  19398  -0.275602  0.431532
# 20  N00060 DRUG_TARGET_PATHWAY hsa04380  21385  -0.113752  0.471593
# 19    D10845 DRUG_TARGET_PATHWAY D07257  14832   0.090285  0.522556
# 10         H00242 DISEASE_GENE HSA:6788  13613   0.147266  0.536750
# 16           H00242 DISEASE_GENE D11034  12303   0.205092  0.551094
# 13  D10845 DRUG_TARGET_PATHWAY hsa05230  10786   0.301698  0.574858
# 17    D04905 DRUG_TARGET_PATHWAY N00399   1186   0.965996  0.724321
# 14         N00060 NETWORK_GENE HSA:5600   3445   0.997908  0.730647
# 15       N00327 DISEASE_PATHWAY HSA:109   1751   1.061760  0.743027
# 18           N00399 NETWORK_GENE N00399   2776   1.570012  0.827785
# 0       hsa04024 PATHWAY_GENE HSA:51196    411   3.652267  0.974723
# 11  D04905 DRUG_TARGET_PATHWAY hsa04728     84   3.821290  0.978570
# 9      D11056 DRUG_TARGET_GENE HSA:3352     80   5.495215  0.995910
# 3   D04905 DRUG_TARGET_PATHWAY hsa05010      1   9.345840  0.999913
# 2          H00242 DISEASE_GENE HSA:6338      1  11.471505  0.999990
# 1   D11034 DRUG_EFFICACY_DISEASE H00409      1  11.471539  0.999990
# 4          N00399 NETWORK_GENE HSA:2790      3  11.556274  0.999990
# 6         N00060 NETWORK_GENE HSA:23401      4  12.050840  0.999994
# 5   D10845 DRUG_TARGET_PATHWAY hsa04610      1  13.813126  0.999999

# %% [markdown]
# #### Insights from link prediction

# %% [markdown]
# We have created a set of **21** facts to check about there possibilities wrt to learned models, out of which few are already in dataset (existing, so should get high scores), few are immpossible and few needs to tested and help us gain meaningful ingights.
# We can observe all the facts existing in dataset gets highest scores (>0.97 and mostlt 0.99).
# We can also observe that fact 9 that is **D11056 connected to HSA:3352** also got high scores (0.995) even though not in dataset, so there might be some correlation between this drug-gene pair . Also, fact 11 has also got high probablity (0.978) even though not in dataset that is **D04905 connected to pathway hsa04728**.

# %% [markdown]
# # Visualisation of embedding in lower dimensions

# %%
# %%capture
# !pip install seaborn adjustText
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
# %matplotlib inline

# %% [markdown]
# Using PCA as a dimensionality reduction algorithm. Principal Component Analysis (PCA) is an unsupervised, non-parametric statistical technique primarily used for dimensionality reduction in machine learning.

# %%
embeddings_2d = PCA(n_components=2).fit_transform(np.array([i for i in entity_embeddings.values()]))
embeddings_2d[:2]
# Out:
# array([[ 0.46288884, -0.15098329],
#        [ 1.8676049 , -0.16473289]], dtype=float32)

# %%
embeddings_2d[0]
# Out:
# array([ 0.46288884, -0.15098329], dtype=float32)

# %% [markdown]
# ##### Plotting in 2D space based on entity type

# %%
def entityType(n):         # Utility functon to return entity type
  if n.startswith("h"):
    return "PATHWAY"
  elif n.startswith("D"):
    return "DRUG"
  elif n.startswith("N"):
    return "NETWORK"
  elif n.startswith("HS"):
    return "GENE"
  else:
    return "DISEASE"

# %%
entityTypeList = list(map(entityType,entities))
print(pd.DataFrame({"Entity": entities[:5],"Type":entityTypeList[:5]}))
# Out:
#    Entity  Type
# 0  D00043  DRUG
# 1  D00045  DRUG
# 2  D00049  DRUG
# 3  D00058  DRUG
# 4  D00059  DRUG

# %%
entityType_df = pd.DataFrame({"entity": entities,
                "type":entityTypeList,
                "embedding1": embeddings_2d[:, 0], 
                "embedding2": embeddings_2d[:, 1],
                })
entityType_df
# Out:
#          entity     type  embedding1  embedding2
# 0        D00043     DRUG    0.462889   -0.150983
# 1        D00045     DRUG    1.867605   -0.164733
# 2        D00049     DRUG   -0.312338   -0.716182
# 3        D00058     DRUG    2.416472    0.094497
# 4        D00059     DRUG    2.441802   -0.217950
# ...         ...      ...         ...         ...
# 16196  hsa05410  PATHWAY    0.735352    0.518668
# 16197  hsa05412  PATHWAY    0.740646    0.416631
# 16198  hsa05414  PATHWAY    0.995991    0.916192
# 16199  hsa05416  PATHWAY    0.077175    0.517493
# 16200  hsa05418  PATHWAY    0.839060    0.847664
#
# [16201 rows x 4 columns]

# %%
def plot_clusters(hue,df,saved=False,figname='default.png'):
  np.random.seed(0)
  plt.figure(figsize=(12, 12))
  plt.title("{} embeddings".format(hue).capitalize())
  ax = sns.scatterplot(data=df, x="embedding1", y="embedding2", hue=hue)
  if saved==True:
    plt.savefig(figname,bbox_inches = 'tight')

# %%
plot_clusters("type",entityType_df)

# %% [markdown]
# # Clustering and plotting

# %%
from ampligraph.discovery import find_clusters
from sklearn.cluster import KMeans

# %%
# https://github.com/prakhargurawa/Machine-Learning-A-Z/blob/main/4_Clustering/k_means_clustering.py
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html
WCSS = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, n_init=50, max_iter=500, random_state=0,init = 'k-means++')
    km.fit(embeddings_2d )
    WCSS.append(km.inertia_)

# plot
plt.plot(range(1, 11), WCSS, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()
# 3 is perfect for now

# %%
clustering_algorithm = KMeans(n_clusters=3, n_init=50, max_iter=500, random_state=0,init = 'k-means++')
clusters = find_clusters(entities, model, clustering_algorithm, mode='entity')

# %%
plot_df = pd.DataFrame({"entity": entities, 
                        "embedding1": embeddings_2d[:, 0], 
                        "embedding2": embeddings_2d[:, 1],
                        "cluster": "cluster" + pd.Series(clusters).astype(str)})
plot_df
# Out:
#          entity  embedding1  embedding2   cluster
# 0        D00043    0.462889   -0.150983  cluster2
# 1        D00045    1.867606   -0.164733  cluster0
# 2        D00049   -0.312329   -0.716175  cluster2
# 3        D00058    2.416472    0.094496  cluster0
# 4        D00059    2.441803   -0.217950  cluster0
# ...         ...         ...         ...       ...
# 16196  hsa05410    0.735353    0.518667  cluster1
# 16197  hsa05412    0.740645    0.416631  cluster1
# 16198  hsa05414    0.995992    0.916192  cluster1
# 16199  hsa05416    0.077176    0.517493  cluster1
# 16200  hsa05418    0.839062    0.847664  cluster1
#
# [16201 rows x 4 columns]

# %%
plot_clusters("cluster",plot_df)

# %% [markdown]
# # Model Selection/ Hyperparameter settings

# %%
import itertools
tf.logging.set_verbosity(tf.logging.ERROR)

ks = [100,200,300]                # dimension of embeddings         
optimizers = ['adam','sgd']       # adam optimizer and stochastic gradient optimizer
optimizers = ['adam']             # adam optimizer 
losss = ['multiclass_nll','bce']  # Multiclass NLL loss and Binary cross entropy loss 
losss = ['multiclass_nll']        # Multiclass NLL loss    
lrs = [1e-3,1e-1]                 # Learning rate for optimizers 
lambdas = [1e-5,1e-2,1e-1]        # regularization constants
ps = [1,2,3]                      # L1,L2 or L3 (nuclear 3-norm) regularization

i = 0
for k,optimizer,loss,lr,lam,p in itertools.product(ks,optimizers,losss,lrs,lambdas,ps):
  print("\n################################################################################################################\n")
  try:
    print("Model configs ( Embedding size : ",k,", Optimizer : ",optimizer,", with learning rate : ",lr,", Loss : ",loss,",regularization type: ",p," regularization constant lambda: ",lam," )")
    model = ComplEx(batches_count=100, 
                  seed=0, 
                  epochs=200, 
                  k=k, 
                  eta=5,
                  optimizer=optimizer, 
                  optimizer_params={'lr':lr},
                  loss=loss,                                 # Multiclass NLL Loss Reference: https://docs.ampligraph.org/en/latest/generated/ampligraph.latent_features.NLLMulticlass.html#ampligraph.latent_features.NLLMulticlass
                  regularizer='LP', 
                  regularizer_params={'p':p, 'lambda':lam},  # The nuclear 3-norm proposed in the ComplEx-N3 from paper LUO18, proves to be effective for DistMult and ComplEx Reference: https://github.com/DeepGraphLearning/KnowledgeGraphEmbedding/issues/6 
                  verbose=False)
    
    start_time = time.time()
    model.fit(data['train'], early_stopping = False)
    print("Execution time: %s seconds." % (time.time() - start_time))
    
    # modelname = './ComplEx_model_'+str(i)+'.pkl'
    # print("Model saved as :",modelname)
    # save_model(model, modelname)
    print("Number : ",i)
    i=i+1

    ranks = evaluate_performance(data['test'],model=model,filter_triples=positives_filter,use_default_protocol=True,verbose=True)

    mrr = mrr_score(ranks)
    print("MRR: %.2f" % (mrr))
    hits_10 = hits_at_n_score(ranks, n=10)
    print("Hits@10: %.2f" % (hits_10))
    hits_3 = hits_at_n_score(ranks, n=3)
    print("Hits@3: %.2f" % (hits_3))
    hits_1 = hits_at_n_score(ranks, n=1)
    print("Hits@1: %.2f" % (hits_1))  
  except Exception as e:
    print("This configuration didn't worked out due to some technical error: ",e)
  print("\n################################################################################################################\n")
# Out:
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  1e-05  )
# Execution time: 86.3718945980072 seconds.
# Number :  0
# MRR: 0.37
# Hits@10: 0.53
# Hits@3: 0.40
# Hits@1: 0.29
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  1e-05  )
# Execution time: 84.59102892875671 seconds.
# Number :  1
# MRR: 0.38
# Hits@10: 0.55
# Hits@3: 0.41
# Hits@1: 0.29
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  1e-05  )
# Execution time: 86.06820583343506 seconds.
# Number :  2
# MRR: 0.38
# Hits@10: 0.55
# Hits@3: 0.41
# Hits@1: 0.29
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.01  )
# Execution time: 83.038321018219 seconds.
# Number :  3
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.01  )
# Execution time: 84.47268342971802 seconds.
# Number :  4
# MRR: 0.24
# Hits@10: 0.42
# Hits@3: 0.27
# Hits@1: 0.16
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.01  )
# Execution time: 85.74758529663086 seconds.
# Number :  5
# MRR: 0.45
# Hits@10: 0.63
# Hits@3: 0.48
# Hits@1: 0.36
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.1  )
# Execution time: 83.60930156707764 seconds.
# Number :  6
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.1  )
# Execution time: 85.15410709381104 seconds.
# Number :  7
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.1  )
# Execution time: 86.02657341957092 seconds.
# Number :  8
# MRR: 0.32
# Hits@10: 0.49
# Hits@3: 0.35
# Hits@1: 0.24
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.01  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.01  )
# Execution time: 85.69112467765808 seconds.
# Number :  9
# MRR: 0.06
# Hits@10: 0.13
# Hits@3: 0.06
# Hits@1: 0.02
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.01  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.1  )
# Execution time: 82.16843390464783 seconds.
# Number :  10
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.1  )
# Execution time: 84.85723185539246 seconds.
# Number :  11
# MRR: 0.02
# Hits@10: 0.04
# Hits@3: 0.01
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  100 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.1  )
# Execution time: 84.26889610290527 seconds.
# Number :  12
# MRR: 0.05
# Hits@10: 0.10
# Hits@3: 0.05
# Hits@1: 0.02
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  1e-05  )
# Execution time: 97.97801041603088 seconds.
# Number :  13
# MRR: 0.37
# Hits@10: 0.54
# Hits@3: 0.40
# Hits@1: 0.29
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  1e-05  )
# Execution time: 102.99678063392639 seconds.
# Number :  14
# MRR: 0.39
# Hits@10: 0.56
# Hits@3: 0.42
# Hits@1: 0.30
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  1e-05  )
# Execution time: 108.39867925643921 seconds.
# Number :  15
# MRR: 0.38
# Hits@10: 0.55
# Hits@3: 0.42
# Hits@1: 0.30
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.01  )
# Execution time: 100.30159139633179 seconds.
# Number :  16
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.01  )
# Execution time: 104.96839690208435 seconds.
# Number :  17
# MRR: 0.22
# Hits@10: 0.40
# Hits@3: 0.24
# Hits@1: 0.14
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.01  )
# Execution time: 107.38420581817627 seconds.
# Number :  18
# MRR: 0.45
# Hits@10: 0.64
# Hits@3: 0.49
# Hits@1: 0.36
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.1  )
# Execution time: 97.93879699707031 seconds.
# Number :  19
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.1  )
# Execution time: 104.48724389076233 seconds.
# Number :  20
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.1  )
# Execution time: 109.04368329048157 seconds.
# Number :  21
# MRR: 0.32
# Hits@10: 0.49
# Hits@3: 0.35
# Hits@1: 0.24
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.01  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.01  )
# Execution time: 105.60626745223999 seconds.
# Number :  22
# MRR: 0.06
# Hits@10: 0.13
# Hits@3: 0.06
# Hits@1: 0.03
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.01  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.1  )
# Execution time: 99.3626856803894 seconds.
# Number :  23
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.1  )
# Execution time: 105.12116932868958 seconds.
# Number :  24
# MRR: 0.02
# Hits@10: 0.04
# Hits@3: 0.01
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  200 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.1  )
# Execution time: 109.21092534065247 seconds.
# Number :  25
# MRR: 0.05
# Hits@10: 0.11
# Hits@3: 0.05
# Hits@1: 0.02
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  1e-05  )
# Execution time: 118.67006087303162 seconds.
# Number :  26
# MRR: 0.37
# Hits@10: 0.54
# Hits@3: 0.40
# Hits@1: 0.29
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  1e-05  )
# Execution time: 130.96265363693237 seconds.
# Number :  27
# MRR: 0.39
# Hits@10: 0.56
# Hits@3: 0.42
# Hits@1: 0.30
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  1e-05  )
# Execution time: 133.99661445617676 seconds.
# Number :  28
# MRR: 0.38
# Hits@10: 0.55
# Hits@3: 0.42
# Hits@1: 0.30
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.01  )
# Execution time: 118.79031610488892 seconds.
# Number :  29
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.01  )
# Execution time: 125.27921080589294 seconds.
# Number :  30
# MRR: 0.22
# Hits@10: 0.40
# Hits@3: 0.24
# Hits@1: 0.14
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.01  )
# Execution time: 136.5050220489502 seconds.
# Number :  31
# MRR: 0.46
# Hits@10: 0.64
# Hits@3: 0.49
# Hits@1: 0.37
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.1  )
# Execution time: 115.31385135650635 seconds.
# Number :  32
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.1  )
# Execution time: 123.3097574710846 seconds.
# Number :  33
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.1  )
# Execution time: 129.98796129226685 seconds.
# Number :  34
# MRR: 0.33
# Hits@10: 0.49
# Hits@3: 0.35
# Hits@1: 0.24
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  1e-05  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.01  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.01  )
# Execution time: 125.93481969833374 seconds.
# Number :  35
# MRR: 0.07
# Hits@10: 0.13
# Hits@3: 0.07
# Hits@1: 0.03
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.01  )
# This configuration didn't worked out due to some technical error:  Loss is inf. Please change the hyperparameters.
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  1  regularization constant lambda:  0.1  )
# Execution time: 118.20304346084595 seconds.
# Number :  36
# MRR: 0.00
# Hits@10: 0.00
# Hits@3: 0.00
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  2  regularization constant lambda:  0.1  )
# Execution time: 127.94831013679504 seconds.
# Number :  37
# MRR: 0.02
# Hits@10: 0.04
# Hits@3: 0.01
# Hits@1: 0.00
#
# ################################################################################################################
#
#
# ################################################################################################################
#
# Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.1 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.1  )
# Execution time: 133.60567045211792 seconds.
# Number :  38
# MRR: 0.04
# Hits@10: 0.09
# Hits@3: 0.04
# Hits@1: 0.01
#
# ################################################################################################################

# %% [markdown]
# # Working with best model
#
# After testing the model with different hyperparameters, we are going to us ethe best performing model from now.

# %%
"""
Model configs ( Embedding size :  300 , Optimizer :  adam , with learning rate :  0.001 , Loss :  multiclass_nll ,regularization type:  3  regularization constant lambda:  0.01  )
Execution time: 136.5050220489502 seconds.
Number :  31
MRR: 0.46
Hits@10: 0.64
Hits@3: 0.49
Hits@1: 0.37
"""
model = ComplEx(batches_count=100, 
                seed=0, 
                epochs=200, 
                k=300, 
                eta=5,
                optimizer='adam', 
                optimizer_params={'lr':1e-3},
                loss='multiclass_nll',                     # Multiclass NLL Loss Reference: https://docs.ampligraph.org/en/latest/generated/ampligraph.latent_features.NLLMulticlass.html#ampligraph.latent_features.NLLMulticlass
                regularizer='LP', 
                regularizer_params={'p':3,'lambda':1e-2},  # The nuclear 3-norm proposed in the ComplEx-N3 from paper LUO18, proves to be effective for DistMult and ComplEx Reference: https://github.com/DeepGraphLearning/KnowledgeGraphEmbedding/issues/6 
                verbose=True)

# Possible loss functions: (Pairwise, max-margin loss),(Absolute margin, max-margin loss),(Self adversarial sampling loss),(Negative log-likelihood loss),(Multiclass NLL Loss),(Binary Cross Entropy Loss)
# Default initializer : Xaviers
# LUO18 : Timothee Lacroix, Nicolas Usunier, and Guillaume Obozinski. Canonical tensor decomposition for knowledge base completion. In International Conference on Machine Learning, 2869–2878. 2018.

# %%
tf.logging.set_verbosity(tf.logging.ERROR)
start_time = time.time()
model.fit(data['train'], early_stopping = False)
print("Execution time: %s seconds." % (time.time() - start_time))
# Out:
# Average ComplEx Loss:   0.188040: 100%|██████████| 200/200 [02:19<00:00,  1.43epoch/s]
# Execution time: 140.59807538986206 seconds.

# %%
save_model(model, './ComplEx_Best_Model')

# %%
ranks = evaluate_performance(data['test'], 
                             model=model, 
                             filter_triples=positives_filter,   # Corruption strategy filter defined above 
                             use_default_protocol=True,         # corrupt subj and obj separately while evaluating
                             verbose=True)
# Out:
# 100%|██████████| 12616/12616 [01:45<00:00, 119.87it/s]

# %%
mrr = mrr_score(ranks)
print("MRR: %.2f" % (mrr))

hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))
# Out:
# MRR: 0.46
# Hits@10: 0.64
# Hits@3: 0.49
# Hits@1: 0.37

# %%
entity_embeddings = dict(zip(entities, model.get_embeddings(entities)))

# %%
len(entity_embeddings['D00043'])
# Out:
# 600

# %%
unseen_filter = np.array(list({tuple(i) for i in np.vstack((positives_filter, X_unseen))}))

# %%
ranks_unseen = evaluate_performance(
    X_unseen, 
    model=model, 
    filter_triples=unseen_filter,   # Corruption strategy filter defined above 
    corrupt_side = 's+o',
    use_default_protocol=False, # corrupt subj and obj separately while evaluating
    verbose=True
)
# Out:
# 100%|██████████| 21/21 [00:00<00:00, 81.47it/s]

# %%
ranks_unseen
# Out:
# array([  236,     2,     2,     1,     2,     1,     1, 19814,  7636,
#          133,  8927,    25, 27812,  3818,   963, 19886, 28037, 25823,
#        16476,  6956, 32017], dtype=int32)

# %%
scores = model.predict(X_unseen)

# %%
scores # direct scores, hard to get insights from these
# Out:
# array([ 3.7047827 ,  4.85122   ,  4.2918644 ,  4.979891  ,  5.8305798 ,
#         5.896208  ,  5.3999615 , -0.2112093 ,  0.08921199,  2.8234715 ,
#         0.07181515,  4.369777  , -0.448929  ,  0.25680685,  1.4401975 ,
#        -0.04409878, -0.20788862, -0.1543378 , -0.05818535,  0.11252733,
#        -0.9277667 ], dtype=float32)

# %%
from scipy.special import expit
probs = expit(scores)
pd.DataFrame(list(zip([' '.join(x) for x in X_unseen],
                      ranks_unseen,
                      np.squeeze(scores),
                      np.squeeze(probs))),
             columns=['statement', 'rank', 'score', 'prob']).sort_values("score")
# Out:
#                               statement   rank     score      prob
# 20  N00060 DRUG_TARGET_PATHWAY hsa04380  32017 -0.927767  0.283378
# 12         N00399 NETWORK_GENE HSA:9217  27812 -0.448929  0.389615
# 7        hsa04024 PATHWAY_GENE HSA:6336  19814 -0.211209  0.447393
# 16           H00242 DISEASE_GENE D11034  28037 -0.207889  0.448214
# 17    D04905 DRUG_TARGET_PATHWAY N00399  25823 -0.154338  0.461492
# 18           N00399 NETWORK_GENE N00399  16476 -0.058185  0.485458
# 15       N00327 DISEASE_PATHWAY HSA:109  19886 -0.044099  0.488977
# 10         H00242 DISEASE_GENE HSA:6788   8927  0.071815  0.517946
# 8      D11056 DRUG_TARGET_GENE HSA:7388   7636  0.089212  0.522288
# 19    D10845 DRUG_TARGET_PATHWAY D07257   6956  0.112527  0.528102
# 13  D10845 DRUG_TARGET_PATHWAY hsa05230   3818  0.256807  0.563851
# 14         N00060 NETWORK_GENE HSA:5600    963  1.440197  0.808485
# 9      D11056 DRUG_TARGET_GENE HSA:3352    133  2.823472  0.943931
# 0       hsa04024 PATHWAY_GENE HSA:51196    236  3.704783  0.975985
# 2          H00242 DISEASE_GENE HSA:6338      2  4.291864  0.986505
# 11  D04905 DRUG_TARGET_PATHWAY hsa04728     25  4.369777  0.987504
# 1   D11034 DRUG_EFFICACY_DISEASE H00409      2  4.851220  0.992242
# 3   D04905 DRUG_TARGET_PATHWAY hsa05010      1  4.979891  0.993172
# 6         N00060 NETWORK_GENE HSA:23401      1  5.399961  0.995504
# 4          N00399 NETWORK_GENE HSA:2790      2  5.830580  0.997072
# 5   D10845 DRUG_TARGET_PATHWAY hsa04610      1  5.896208  0.997258

# %%
embeddings_2d = PCA(n_components=2).fit_transform(np.array([i for i in entity_embeddings.values()]))
embeddings_2d[:2]
# Out:
# array([[-0.25646207,  0.16480167],
#        [-0.56086737,  0.6127884 ]], dtype=float32)

# %%
entityTypeList = list(map(entityType,entities))
print(pd.DataFrame({"Entity": entities[:5],"Type":entityTypeList[:5]}))
# Out:
#    Entity  Type
# 0  D00043  DRUG
# 1  D00045  DRUG
# 2  D00049  DRUG
# 3  D00058  DRUG
# 4  D00059  DRUG

# %%
entityType_df = pd.DataFrame({"entity": entities,
                "type":entityTypeList,
                "embedding1": embeddings_2d[:, 0], 
                "embedding2": embeddings_2d[:, 1],
                })
entityType_df
# Out:
#          entity     type  embedding1  embedding2
# 0        D00043     DRUG   -0.256462    0.164802
# 1        D00045     DRUG   -0.560867    0.612788
# 2        D00049     DRUG   -0.673182   -0.091692
# 3        D00058     DRUG   -0.700761    0.769173
# 4        D00059     DRUG   -0.763181    0.851906
# ...         ...      ...         ...         ...
# 16196  hsa05410  PATHWAY   -0.090857   -0.192814
# 16197  hsa05412  PATHWAY   -0.086063   -0.167628
# 16198  hsa05414  PATHWAY   -0.166652   -0.194720
# 16199  hsa05416  PATHWAY   -0.043784   -0.340017
# 16200  hsa05418  PATHWAY   -0.147724   -0.230022
#
# [16201 rows x 4 columns]

# %%
plot_clusters("type",entityType_df,saved=True,figname='ComplEx2DEntity.png')

# %%
# https://github.com/prakhargurawa/Machine-Learning-A-Z/blob/main/4_Clustering/k_means_clustering.py
# https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html
WCSS = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, n_init=50, max_iter=500, random_state=0,init = 'k-means++')
    km.fit(embeddings_2d)
    WCSS.append(km.inertia_)

# plot
plt.plot(range(1, 11), WCSS, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.savefig('KmeansWCSS_ComplEx.png')
plt.show()
# 4 is perfect for now

# %%
clustering_algorithm = KMeans(n_clusters=3, n_init=50, max_iter=500, random_state=0,init = 'k-means++')
clusters = find_clusters(entities, model, clustering_algorithm, mode='entity')

# %%
plot_df = pd.DataFrame({"entity": entities, 
                        "embedding1": embeddings_2d[:, 0], 
                        "embedding2": embeddings_2d[:, 1],
                        "cluster": "cluster" + pd.Series(clusters).astype(str)})
plot_df
# Out:
#          entity  embedding1  embedding2   cluster
# 0        D00043   -0.256465    0.164760  cluster2
# 1        D00045   -0.560868    0.612857  cluster0
# 2        D00049   -0.673181   -0.091664  cluster2
# 3        D00058   -0.700762    0.769203  cluster0
# 4        D00059   -0.763181    0.851762  cluster0
# ...         ...         ...         ...       ...
# 16196  hsa05410   -0.090856   -0.192862  cluster2
# 16197  hsa05412   -0.086063   -0.167675  cluster2
# 16198  hsa05414   -0.166650   -0.194749  cluster2
# 16199  hsa05416   -0.043785   -0.340142  cluster2
# 16200  hsa05418   -0.147721   -0.230190  cluster2
#
# [16201 rows x 4 columns]

# %%
plot_clusters("cluster",plot_df,saved=True,figname='ComplEx2DCluster.png')

# %%
plt.plot([0, 1, 2, 3, 4], [0, 3, 5, 9, 11])
plt.savefig('books_read.png')
